# %% [markdown]
# #### Importing libraries

# %%
import copy
from pprint import pprint

# %% [markdown]
# #### Game Tree Setup

# %%
# dont track moves like 'l' and 'r' because there are too many

game_board_map = [[0,1,2], [3,4,5], [6,7,8]]

game_board_state = {
    '[[None, None, None], [None, None, None], [None, None, None]]': {
        'player': 'X',
        'states': [],
        'utility': None
    } 
}
init_state = [[None, None, None], [None, None, None], [None, None, None]]

# %% [markdown]
# #### Generate Successor States

# %%
def get_successor_states(current_state, player):
    successor_states = []
    for x in range(len(current_state)):
        for y in range(len(current_state[x])):
            if current_state[x][y] is None:
                new_state = copy.deepcopy(current_state)
                new_state[x][y] = player
                successor_states.append(new_state)
                
    return successor_states

get_successor_states(init_state, 'X')
# Out:
# [[['X', None, None], [None, None, None], [None, None, None]],
#  [[None, 'X', None], [None, None, None], [None, None, None]],
#  [[None, None, 'X'], [None, None, None], [None, None, None]],
#  [[None, None, None], ['X', None, None], [None, None, None]],
#  [[None, None, None], [None, 'X', None], [None, None, None]],
#  [[None, None, None], [None, None, 'X'], [None, None, None]],
#  [[None, None, None], [None, None, None], ['X', None, None]],
#  [[None, None, None], [None, None, None], [None, 'X', None]],
#  [[None, None, None], [None, None, None], [None, None, 'X']]]

# %%
game_board_state[str(init_state)]['states'] = get_successor_states(init_state, 'X')

# %%
game_board_state
# Out:
# {'[[None, None, None], [None, None, None], [None, None, None]]': {'player': 'X',
#   'states': [[['X', None, None], [None, None, None], [None, None, None]],
#    [[None, 'X', None], [None, None, None], [None, None, None]],
#    [[None, None, 'X'], [None, None, None], [None, None, None]],
#    [[None, None, None], ['X', None, None], [None, None, None]],
#    [[None, None, None], [None, 'X', None], [None, None, None]],
#    [[None, None, None], [None, None, 'X'], [None, None, None]],
#    [[None, None, None], [None, None, None], ['X', None, None]],
#    [[None, None, None], [None, None, None], [None, 'X', None]],
#    [[None, None, None], [None, None, None], [None, None, 'X']]]}}

# %% [markdown]
# #### Check if state is Terminal State

# %%
def isTerminal(state):
    all_filled = True
    for row in state:
        for space in row:
            if space is None:
                all_filled = False
    return all_filled

isTerminal([['X', 'Y', 'X'], ['X', 'Y', 'X'], ['X', 'Y', 'X']])
# Out:
# True

# %%
def return_positions(state, player):
    positions = []
    for x in range(len(state)):
        for y in range(len(state[x])):
            if state[x][y] == player:
                positions.append(y + x*3)
    return positions

return_positions([['X', None, None], [None, 'X', None], [None, None, 'X']], 'X')
# Out:
# [0, 4, 8]

# %%
[0,1,2] in [0,1,2,3]
# Out:
# False

# %%
def check_if_winning_state(state):
    positions_where_player_X = return_positions(state, 'X')
    positions_where_player_Y = return_positions(state, 'Y')
    if 0 in positions_where_player_X and 1 in positions_where_player_X and 2 in positions_where_player_X:
        return True, 'X'
    if 3 in positions_where_player_X and 4 in positions_where_player_X and 5 in positions_where_player_X:
        return True, 'X'
    if 6 in positions_where_player_X and 7 in positions_where_player_X and 8 in positions_where_player_X:
        return True, 'X'
    if 0 in positions_where_player_X and 4 in positions_where_player_X and 8 in positions_where_player_X:
        return True, 'X'
    if 2 in positions_where_player_X and 4 in positions_where_player_X and 6 in positions_where_player_X:
        return True, 'X'
    
    
    if 0 in positions_where_player_Y and 1 in positions_where_player_Y and 2 in positions_where_player_Y:
        return True, 'Y'
    if 3 in positions_where_player_Y and 4 in positions_where_player_Y and 5 in positions_where_player_Y:
        return True, 'Y'
    if 6 in positions_where_player_Y and 7 in positions_where_player_Y and 8 in positions_where_player_Y:
        return True, 'Y'
    if 0 in positions_where_player_Y and 4 in positions_where_player_Y and 8 in positions_where_player_Y:
        return True, 'Y'
    if 2 in positions_where_player_Y and 4 in positions_where_player_Y and 6 in positions_where_player_Y:
        return True, 'Y'
    return False, None

check_if_winning_state([['Y', None, None], ['Y', 'Y', 'Y'], [None, 'Y', None]])
# Out:
# (True, 'Y')

# %%
get_successor_states(init_state, 'X')
# Out:
# [[['X', None, None], [None, None, None], [None, None, None]],
#  [[None, 'X', None], [None, None, None], [None, None, None]],
#  [[None, None, 'X'], [None, None, None], [None, None, None]],
#  [[None, None, None], ['X', None, None], [None, None, None]],
#  [[None, None, None], [None, 'X', None], [None, None, None]],
#  [[None, None, None], [None, None, 'X'], [None, None, None]],
#  [[None, None, None], [None, None, None], ['X', None, None]],
#  [[None, None, None], [None, None, None], [None, 'X', None]],
#  [[None, None, None], [None, None, None], [None, None, 'X']]]

# %%
[1,2,3].pop(0)
# Out:
# 1

# %%
game_board_state = {
    
}

# %%
def generate_game_space_by_level(state):
    if state == init_state:
    
        states_to_be_generated_by_level = [[init_state]]
        level = 0
        states_generated_by_level = []
        all_states_generated = []
        player = 'X'
        while states_to_be_generated_by_level and level < 10:
            # all states to be generated at this level
            print ("Current Level:", level)
            if level%2 == 0:
                player = 'X'
            else:
                player = 'Y'
            states_to_be_generated_at_level = states_to_be_generated_by_level.pop(0)
            print(len(states_to_be_generated_at_level))
            #print ("Current states:............") 
            #print (states_to_be_generated_at_level)
            
            # generate all states at this level
            next_level_successor_states = []
            for current_level_state in states_to_be_generated_at_level:
                if check_if_winning_state(current_level_state)[0] or isTerminal(current_level_state):
                    continue
                game_board_state[str(current_level_state)] = {
                    'states': None
                }
                
                successor_states = get_successor_states(current_level_state, player)
                
                game_board_state[str(current_level_state)]['states'] = successor_states
                
                for successor_state in successor_states:
                    next_level_successor_states.append(successor_state)
            states_to_be_generated_by_level.append(next_level_successor_states)
            level += 1
            #print ("Next level states:............")
            #print (next_level_successor_states)
            
            #print(game_board_state)
            
generate_game_space_by_level(init_state)
# Out:
# Current Level: 0
# 1
# Current Level: 1
# 9
# Current Level: 2
# 72
# Current Level: 3
# 504
# Current Level: 4
# 3024
# Current Level: 5
# 15120
# Current Level: 6
# 56880
# Current Level: 7
# 160488
# Current Level: 8
# 260064
# Current Level: 9
# 210816

# %%
check_if_winning_state([[None, 'Y', 'Y'], ['Y', 'X', 'X'], ['Y', 'X', 'X']])
# Out:
# (False, None)

# %%
for key in game_board_state.keys():
    print (key)
# Out:
# [[None, None, None], [None, None, None], [None, None, None]]
# [['X', None, None], [None, None, None], [None, None, None]]
# [[None, 'X', None], [None, None, None], [None, None, None]]
# [[None, None, 'X'], [None, None, None], [None, None, None]]
# [[None, None, None], ['X', None, None], [None, None, None]]
# [[None, None, None], [None, 'X', None], [None, None, None]]
# [[None, None, None], [None, None, 'X'], [None, None, None]]
# [[None, None, None], [None, None, None], ['X', None, None]]
# [[None, None, None], [None, None, None], [None, 'X', None]]
# [[None, None, None], [None, None, None], [None, None, 'X']]
# [['Y', None, None], [None, None, None], [None, None, 'X']]
# [[None, 'Y', None], [None, None, None], [None, None, 'X']]
# [[None, None, 'Y'], [None, None, None], [None, None, 'X']]
# [[None, None, None], ['Y', None, None], [None, None, 'X']]
# [[None, None, None], [None, 'Y', None], [None, None, 'X']]
# [[None, None, None], [None, None, 'Y'], [None, None, 'X']]
# [[None, None, None], [None, None, None], ['Y', None, 'X']]
# [[None, None, None], [None, None, None], [None, 'Y', 'X']]
# [['X', None, None], [None, None, None], [None, 'Y', 'X']]
# [[None, 'X', None], [None, None, None], [None, 'Y', 'X']]
# [[None, None, 'X'], [None, None, None], [None, 'Y', 'X']]
# [[None, None, None], ['X', None, None], [None, 'Y', 'X']]
# [[None, None, None], [None, 'X', None], [None, 'Y', 'X']]
# [[None, None, None], [None, None, 'X'], [None, 'Y', 'X']]
# [[None, None, None], [None, None, None], ['X', 'Y', 'X']]
# [['Y', None, None], [None, None, None], ['X', 'Y', 'X']]
# [[None, 'Y', None], [None, None, None], ['X', 'Y', 'X']]
# [[None, None, 'Y'], [None, None, None], ['X', 'Y', 'X']]
# [[None, None, None], ['Y', None, None], ['X', 'Y', 'X']]
# [[None, None, None], [None, 'Y', None], ['X', 'Y', 'X']]
# [[None, None, None], [None, None, 'Y'], ['X', 'Y', 'X']]
# [['X', None, None], [None, None, 'Y'], ['X', 'Y', 'X']]
# [[None, 'X', None], [None, None, 'Y'], ['X', 'Y', 'X']]
# [[None, None, 'X'], [None, None, 'Y'], ['X', 'Y', 'X']]
# [[None, None, None], ['X', None, 'Y'], ['X', 'Y', 'X']]
# [[None, None, None], [None, 'X', 'Y'], ['X', 'Y', 'X']]
# [['Y', None, None], [None, 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, 'Y', None], [None, 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, None, 'Y'], [None, 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, None, None], ['Y', 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, 'X', None], ['Y', 'X', 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', None], ['Y', 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, 'X', 'Y'], ['Y', 'X', 'Y'], ['X', 'Y', 'X']]
# [['X', 'Y', None], [None, None, None], [None, None, None]]
# [['X', None, 'Y'], [None, None, None], [None, None, None]]
# [['X', None, None], ['Y', None, None], [None, None, None]]
# [['X', None, None], [None, 'Y', None], [None, None, None]]
# [['X', None, None], [None, None, 'Y'], [None, None, None]]
# [['X', None, None], [None, None, None], ['Y', None, None]]
# [['X', None, None], [None, None, None], [None, 'Y', None]]
# [['X', None, None], [None, None, None], [None, None, 'Y']]
# [['Y', 'X', None], [None, None, None], [None, None, None]]
# [[None, 'X', 'Y'], [None, None, None], [None, None, None]]
# [[None, 'X', None], ['Y', None, None], [None, None, None]]
# [[None, 'X', None], [None, 'Y', None], [None, None, None]]
# [[None, 'X', None], [None, None, 'Y'], [None, None, None]]
# [[None, 'X', None], [None, None, None], ['Y', None, None]]
# [[None, 'X', None], [None, None, None], [None, 'Y', None]]
# [[None, 'X', None], [None, None, None], [None, None, 'Y']]
# [['Y', None, 'X'], [None, None, None], [None, None, None]]
# [[None, 'Y', 'X'], [None, None, None], [None, None, None]]
# [[None, None, 'X'], ['Y', None, None], [None, None, None]]
# [[None, None, 'X'], [None, 'Y', None], [None, None, None]]
# [[None, None, 'X'], [None, None, 'Y'], [None, None, None]]
# [[None, None, 'X'], [None, None, None], ['Y', None, None]]
# [[None, None, 'X'], [None, None, None], [None, 'Y', None]]
# [[None, None, 'X'], [None, None, None], [None, None, 'Y']]
# [['Y', None, None], ['X', None, None], [None, None, None]]
# [[None, 'Y', None], ['X', None, None], [None, None, None]]
# [[None, None, 'Y'], ['X', None, None], [None, None, None]]
# [[None, None, None], ['X', 'Y', None], [None, None, None]]
# [[None, None, None], ['X', None, 'Y'], [None, None, None]]
# [[None, None, None], ['X', None, None], ['Y', None, None]]
# [[None, None, None], ['X', None, None], [None, 'Y', None]]
# [[None, None, None], ['X', None, None], [None, None, 'Y']]
# [['Y', None, None], [None, 'X', None], [None, None, None]]
# [[None, 'Y', None], [None, 'X', None], [None, None, None]]
# [[None, None, 'Y'], [None, 'X', None], [None, None, None]]
# [[None, None, None], ['Y', 'X', None], [None, None, None]]
# [[None, None, None], [None, 'X', 'Y'], [None, None, None]]
# [[None, None, None], [None, 'X', None], ['Y', None, None]]
# [[None, None, None], [None, 'X', None], [None, 'Y', None]]
# [[None, None, None], [None, 'X', None], [None, None, 'Y']]
# [['Y', None, None], [None, None, 'X'], [None, None, None]]
# [[None, 'Y', None], [None, None, 'X'], [None, None, None]]
# [[None, None, 'Y'], [None, None, 'X'], [None, None, None]]
# [[None, None, None], ['Y', None, 'X'], [None, None, None]]
# [[None, None, None], [None, 'Y', 'X'], [None, None, None]]
# [[None, None, None], [None, None, 'X'], ['Y', None, None]]
# [[None, None, None], [None, None, 'X'], [None, 'Y', None]]
# [[None, None, None], [None, None, 'X'], [None, None, 'Y']]
# [['Y', None, None], [None, None, None], ['X', None, None]]
# [[None, 'Y', None], [None, None, None], ['X', None, None]]
# [[None, None, 'Y'], [None, None, None], ['X', None, None]]
# [[None, None, None], ['Y', None, None], ['X', None, None]]
# [[None, None, None], [None, 'Y', None], ['X', None, None]]
# [[None, None, None], [None, None, 'Y'], ['X', None, None]]
# [[None, None, None], [None, None, None], ['X', 'Y', None]]
# [[None, None, None], [None, None, None], ['X', None, 'Y']]
# [['Y', None, None], [None, None, None], [None, 'X', None]]
# [[None, 'Y', None], [None, None, None], [None, 'X', None]]
# [[None, None, 'Y'], [None, None, None], [None, 'X', None]]
# [[None, None, None], ['Y', None, None], [None, 'X', None]]
# [[None, None, None], [None, 'Y', None], [None, 'X', None]]
# [[None, None, None], [None, None, 'Y'], [None, 'X', None]]
# [[None, None, None], [None, None, None], ['Y', 'X', None]]
# [[None, None, None], [None, None, None], [None, 'X', 'Y']]
# [['X', 'Y', 'X'], [None, None, None], [None, None, None]]
# [['X', 'Y', None], ['X', None, None], [None, None, None]]
# [['X', 'Y', None], [None, 'X', None], [None, None, None]]
# [['X', 'Y', None], [None, None, 'X'], [None, None, None]]
# [['X', 'Y', None], [None, None, None], ['X', None, None]]
# [['X', 'Y', None], [None, None, None], [None, 'X', None]]
# [['X', 'Y', None], [None, None, None], [None, None, 'X']]
# [['X', 'X', 'Y'], [None, None, None], [None, None, None]]
# [['X', None, 'Y'], ['X', None, None], [None, None, None]]
# [['X', None, 'Y'], [None, 'X', None], [None, None, None]]
# [['X', None, 'Y'], [None, None, 'X'], [None, None, None]]
# [['X', None, 'Y'], [None, None, None], ['X', None, None]]
# [['X', None, 'Y'], [None, None, None], [None, 'X', None]]
# [['X', None, 'Y'], [None, None, None], [None, None, 'X']]
# [['X', 'X', None], ['Y', None, None], [None, None, None]]
# [['X', None, 'X'], ['Y', None, None], [None, None, None]]
# [['X', None, None], ['Y', 'X', None], [None, None, None]]
# [['X', None, None], ['Y', None, 'X'], [None, None, None]]
# [['X', None, None], ['Y', None, None], ['X', None, None]]
# [['X', None, None], ['Y', None, None], [None, 'X', None]]
# [['X', None, None], ['Y', None, None], [None, None, 'X']]
# [['X', 'X', None], [None, 'Y', None], [None, None, None]]
# [['X', None, 'X'], [None, 'Y', None], [None, None, None]]
# [['X', None, None], ['X', 'Y', None], [None, None, None]]
# [['X', None, None], [None, 'Y', 'X'], [None, None, None]]
# [['X', None, None], [None, 'Y', None], ['X', None, None]]
# [['X', None, None], [None, 'Y', None], [None, 'X', None]]
# [['X', None, None], [None, 'Y', None], [None, None, 'X']]
# [['X', 'X', None], [None, None, 'Y'], [None, None, None]]
# [['X', None, 'X'], [None, None, 'Y'], [None, None, None]]
# [['X', None, None], ['X', None, 'Y'], [None, None, None]]
# [['X', None, None], [None, 'X', 'Y'], [None, None, None]]
# [['X', None, None], [None, None, 'Y'], ['X', None, None]]
# [['X', None, None], [None, None, 'Y'], [None, 'X', None]]
# [['X', None, None], [None, None, 'Y'], [None, None, 'X']]
# [['X', 'X', None], [None, None, None], ['Y', None, None]]
# [['X', None, 'X'], [None, None, None], ['Y', None, None]]
# [['X', None, None], ['X', None, None], ['Y', None, None]]
# [['X', None, None], [None, 'X', None], ['Y', None, None]]
# [['X', None, None], [None, None, 'X'], ['Y', None, None]]
# [['X', None, None], [None, None, None], ['Y', 'X', None]]
# [['X', None, None], [None, None, None], ['Y', None, 'X']]
# [['X', 'X', None], [None, None, None], [None, 'Y', None]]
# [['X', None, 'X'], [None, None, None], [None, 'Y', None]]
# [['X', None, None], ['X', None, None], [None, 'Y', None]]
# [['X', None, None], [None, 'X', None], [None, 'Y', None]]
# [['X', None, None], [None, None, 'X'], [None, 'Y', None]]
# [['X', None, None], [None, None, None], ['X', 'Y', None]]
# [['X', 'X', None], [None, None, None], [None, None, 'Y']]
# [['X', None, 'X'], [None, None, None], [None, None, 'Y']]
# [['X', None, None], ['X', None, None], [None, None, 'Y']]
# [['X', None, None], [None, 'X', None], [None, None, 'Y']]
# [['X', None, None], [None, None, 'X'], [None, None, 'Y']]
# [['X', None, None], [None, None, None], ['X', None, 'Y']]
# [['X', None, None], [None, None, None], [None, 'X', 'Y']]
# [['Y', 'X', 'X'], [None, None, None], [None, None, None]]
# [['Y', 'X', None], ['X', None, None], [None, None, None]]
# [['Y', 'X', None], [None, 'X', None], [None, None, None]]
# [['Y', 'X', None], [None, None, 'X'], [None, None, None]]
# [['Y', 'X', None], [None, None, None], ['X', None, None]]
# [['Y', 'X', None], [None, None, None], [None, 'X', None]]
# [['Y', 'X', None], [None, None, None], [None, None, 'X']]
# [[None, 'X', 'Y'], ['X', None, None], [None, None, None]]
# [[None, 'X', 'Y'], [None, 'X', None], [None, None, None]]
# [[None, 'X', 'Y'], [None, None, 'X'], [None, None, None]]
# [[None, 'X', 'Y'], [None, None, None], ['X', None, None]]
# [[None, 'X', 'Y'], [None, None, None], [None, 'X', None]]
# [[None, 'X', 'Y'], [None, None, None], [None, None, 'X']]
# [[None, 'X', 'X'], ['Y', None, None], [None, None, None]]
# [[None, 'X', None], ['Y', 'X', None], [None, None, None]]
# [[None, 'X', None], ['Y', None, 'X'], [None, None, None]]
# [[None, 'X', None], ['Y', None, None], ['X', None, None]]
# [[None, 'X', None], ['Y', None, None], [None, 'X', None]]
# [[None, 'X', None], ['Y', None, None], [None, None, 'X']]
# [[None, 'X', 'X'], [None, 'Y', None], [None, None, None]]
# [[None, 'X', None], ['X', 'Y', None], [None, None, None]]
# [[None, 'X', None], [None, 'Y', 'X'], [None, None, None]]
# [[None, 'X', None], [None, 'Y', None], ['X', None, None]]
# [[None, 'X', None], [None, 'Y', None], [None, 'X', None]]
# [[None, 'X', None], [None, 'Y', None], [None, None, 'X']]
# [[None, 'X', 'X'], [None, None, 'Y'], [None, None, None]]
# [[None, 'X', None], ['X', None, 'Y'], [None, None, None]]
# [[None, 'X', None], [None, 'X', 'Y'], [None, None, None]]
# [[None, 'X', None], [None, None, 'Y'], ['X', None, None]]
# [[None, 'X', None], [None, None, 'Y'], [None, 'X', None]]
# [[None, 'X', None], [None, None, 'Y'], [None, None, 'X']]
# [[None, 'X', 'X'], [None, None, None], ['Y', None, None]]
# [[None, 'X', None], ['X', None, None], ['Y', None, None]]
# [[None, 'X', None], [None, 'X', None], ['Y', None, None]]
# [[None, 'X', None], [None, None, 'X'], ['Y', None, None]]
# [[None, 'X', None], [None, None, None], ['Y', 'X', None]]
# [[None, 'X', None], [None, None, None], ['Y', None, 'X']]
# [[None, 'X', 'X'], [None, None, None], [None, 'Y', None]]
# [[None, 'X', None], ['X', None, None], [None, 'Y', None]]
# [[None, 'X', None], [None, 'X', None], [None, 'Y', None]]
# [[None, 'X', None], [None, None, 'X'], [None, 'Y', None]]
# [[None, 'X', None], [None, None, None], ['X', 'Y', None]]
# [[None, 'X', 'X'], [None, None, None], [None, None, 'Y']]
# [[None, 'X', None], ['X', None, None], [None, None, 'Y']]
# [[None, 'X', None], [None, 'X', None], [None, None, 'Y']]
# [[None, 'X', None], [None, None, 'X'], [None, None, 'Y']]
# [[None, 'X', None], [None, None, None], ['X', None, 'Y']]
# [[None, 'X', None], [None, None, None], [None, 'X', 'Y']]
# [['Y', None, 'X'], ['X', None, None], [None, None, None]]
# [['Y', None, 'X'], [None, 'X', None], [None, None, None]]
# [['Y', None, 'X'], [None, None, 'X'], [None, None, None]]
# [['Y', None, 'X'], [None, None, None], ['X', None, None]]
# [['Y', None, 'X'], [None, None, None], [None, 'X', None]]
# [['Y', None, 'X'], [None, None, None], [None, None, 'X']]
# [[None, 'Y', 'X'], ['X', None, None], [None, None, None]]
# [[None, 'Y', 'X'], [None, 'X', None], [None, None, None]]
# [[None, 'Y', 'X'], [None, None, 'X'], [None, None, None]]
# [[None, 'Y', 'X'], [None, None, None], ['X', None, None]]
# [[None, 'Y', 'X'], [None, None, None], [None, 'X', None]]
# [[None, 'Y', 'X'], [None, None, None], [None, None, 'X']]
# [[None, None, 'X'], ['Y', 'X', None], [None, None, None]]
# [[None, None, 'X'], ['Y', None, 'X'], [None, None, None]]
# [[None, None, 'X'], ['Y', None, None], ['X', None, None]]
# [[None, None, 'X'], ['Y', None, None], [None, 'X', None]]
# [[None, None, 'X'], ['Y', None, None], [None, None, 'X']]
# [[None, None, 'X'], ['X', 'Y', None], [None, None, None]]
# [[None, None, 'X'], [None, 'Y', 'X'], [None, None, None]]
# [[None, None, 'X'], [None, 'Y', None], ['X', None, None]]
# [[None, None, 'X'], [None, 'Y', None], [None, 'X', None]]
# [[None, None, 'X'], [None, 'Y', None], [None, None, 'X']]
# [[None, None, 'X'], ['X', None, 'Y'], [None, None, None]]
# [[None, None, 'X'], [None, 'X', 'Y'], [None, None, None]]
# [[None, None, 'X'], [None, None, 'Y'], ['X', None, None]]
# [[None, None, 'X'], [None, None, 'Y'], [None, 'X', None]]
# [[None, None, 'X'], [None, None, 'Y'], [None, None, 'X']]
# [[None, None, 'X'], ['X', None, None], ['Y', None, None]]
# [[None, None, 'X'], [None, 'X', None], ['Y', None, None]]
# [[None, None, 'X'], [None, None, 'X'], ['Y', None, None]]
# [[None, None, 'X'], [None, None, None], ['Y', 'X', None]]
# [[None, None, 'X'], [None, None, None], ['Y', None, 'X']]
# [[None, None, 'X'], ['X', None, None], [None, 'Y', None]]
# [[None, None, 'X'], [None, 'X', None], [None, 'Y', None]]
# [[None, None, 'X'], [None, None, 'X'], [None, 'Y', None]]
# [[None, None, 'X'], [None, None, None], ['X', 'Y', None]]
# [[None, None, 'X'], ['X', None, None], [None, None, 'Y']]
# [[None, None, 'X'], [None, 'X', None], [None, None, 'Y']]
# [[None, None, 'X'], [None, None, 'X'], [None, None, 'Y']]
# [[None, None, 'X'], [None, None, None], ['X', None, 'Y']]
# [[None, None, 'X'], [None, None, None], [None, 'X', 'Y']]
# [['Y', None, None], ['X', 'X', None], [None, None, None]]
# [['Y', None, None], ['X', None, 'X'], [None, None, None]]
# [['Y', None, None], ['X', None, None], ['X', None, None]]
# [['Y', None, None], ['X', None, None], [None, 'X', None]]
# [['Y', None, None], ['X', None, None], [None, None, 'X']]
# [[None, 'Y', None], ['X', 'X', None], [None, None, None]]
# [[None, 'Y', None], ['X', None, 'X'], [None, None, None]]
# [[None, 'Y', None], ['X', None, None], ['X', None, None]]
# [[None, 'Y', None], ['X', None, None], [None, 'X', None]]
# [[None, 'Y', None], ['X', None, None], [None, None, 'X']]
# [[None, None, 'Y'], ['X', 'X', None], [None, None, None]]
# [[None, None, 'Y'], ['X', None, 'X'], [None, None, None]]
# [[None, None, 'Y'], ['X', None, None], ['X', None, None]]
# [[None, None, 'Y'], ['X', None, None], [None, 'X', None]]
# [[None, None, 'Y'], ['X', None, None], [None, None, 'X']]
# [[None, None, None], ['X', 'Y', 'X'], [None, None, None]]
# [[None, None, None], ['X', 'Y', None], ['X', None, None]]
# [[None, None, None], ['X', 'Y', None], [None, 'X', None]]
# [[None, None, None], ['X', 'Y', None], [None, None, 'X']]
# [[None, None, None], ['X', 'X', 'Y'], [None, None, None]]
# [[None, None, None], ['X', None, 'Y'], ['X', None, None]]
# [[None, None, None], ['X', None, 'Y'], [None, 'X', None]]
# [[None, None, None], ['X', None, 'Y'], [None, None, 'X']]
# [[None, None, None], ['X', 'X', None], ['Y', None, None]]
# [[None, None, None], ['X', None, 'X'], ['Y', None, None]]
# [[None, None, None], ['X', None, None], ['Y', 'X', None]]
# [[None, None, None], ['X', None, None], ['Y', None, 'X']]
# [[None, None, None], ['X', 'X', None], [None, 'Y', None]]
# [[None, None, None], ['X', None, 'X'], [None, 'Y', None]]
# [[None, None, None], ['X', None, None], ['X', 'Y', None]]
# [[None, None, None], ['X', 'X', None], [None, None, 'Y']]
# [[None, None, None], ['X', None, 'X'], [None, None, 'Y']]
# [[None, None, None], ['X', None, None], ['X', None, 'Y']]
# [[None, None, None], ['X', None, None], [None, 'X', 'Y']]
# [['Y', None, None], [None, 'X', 'X'], [None, None, None]]
# [['Y', None, None], [None, 'X', None], ['X', None, None]]
# [['Y', None, None], [None, 'X', None], [None, 'X', None]]
# [['Y', None, None], [None, 'X', None], [None, None, 'X']]
# [[None, 'Y', None], [None, 'X', 'X'], [None, None, None]]
# [[None, 'Y', None], [None, 'X', None], ['X', None, None]]
# [[None, 'Y', None], [None, 'X', None], [None, 'X', None]]
# [[None, 'Y', None], [None, 'X', None], [None, None, 'X']]
# [[None, None, 'Y'], [None, 'X', 'X'], [None, None, None]]
# [[None, None, 'Y'], [None, 'X', None], ['X', None, None]]
# [[None, None, 'Y'], [None, 'X', None], [None, 'X', None]]
# [[None, None, 'Y'], [None, 'X', None], [None, None, 'X']]
# [[None, None, None], ['Y', 'X', 'X'], [None, None, None]]
# [[None, None, None], ['Y', 'X', None], ['X', None, None]]
# [[None, None, None], ['Y', 'X', None], [None, 'X', None]]
# [[None, None, None], ['Y', 'X', None], [None, None, 'X']]
# [[None, None, None], [None, 'X', 'Y'], ['X', None, None]]
# [[None, None, None], [None, 'X', 'Y'], [None, 'X', None]]
# [[None, None, None], [None, 'X', 'Y'], [None, None, 'X']]
# [[None, None, None], [None, 'X', 'X'], ['Y', None, None]]
# [[None, None, None], [None, 'X', None], ['Y', 'X', None]]
# [[None, None, None], [None, 'X', None], ['Y', None, 'X']]
# [[None, None, None], [None, 'X', 'X'], [None, 'Y', None]]
# [[None, None, None], [None, 'X', None], ['X', 'Y', None]]
# [[None, None, None], [None, 'X', 'X'], [None, None, 'Y']]
# [[None, None, None], [None, 'X', None], ['X', None, 'Y']]
# [[None, None, None], [None, 'X', None], [None, 'X', 'Y']]
# [['Y', None, None], [None, None, 'X'], ['X', None, None]]
# [['Y', None, None], [None, None, 'X'], [None, 'X', None]]
# [['Y', None, None], [None, None, 'X'], [None, None, 'X']]
# [[None, 'Y', None], [None, None, 'X'], ['X', None, None]]
# [[None, 'Y', None], [None, None, 'X'], [None, 'X', None]]
# [[None, 'Y', None], [None, None, 'X'], [None, None, 'X']]
# [[None, None, 'Y'], [None, None, 'X'], ['X', None, None]]
# [[None, None, 'Y'], [None, None, 'X'], [None, 'X', None]]
# [[None, None, 'Y'], [None, None, 'X'], [None, None, 'X']]
# [[None, None, None], ['Y', None, 'X'], ['X', None, None]]
# [[None, None, None], ['Y', None, 'X'], [None, 'X', None]]
# [[None, None, None], ['Y', None, 'X'], [None, None, 'X']]
# [[None, None, None], [None, 'Y', 'X'], ['X', None, None]]
# [[None, None, None], [None, 'Y', 'X'], [None, 'X', None]]
# [[None, None, None], [None, 'Y', 'X'], [None, None, 'X']]
# [[None, None, None], [None, None, 'X'], ['Y', 'X', None]]
# [[None, None, None], [None, None, 'X'], ['Y', None, 'X']]
# [[None, None, None], [None, None, 'X'], ['X', 'Y', None]]
# [[None, None, None], [None, None, 'X'], ['X', None, 'Y']]
# [[None, None, None], [None, None, 'X'], [None, 'X', 'Y']]
# [['Y', None, None], [None, None, None], ['X', 'X', None]]
# [['Y', None, None], [None, None, None], ['X', None, 'X']]
# [[None, 'Y', None], [None, None, None], ['X', 'X', None]]
# [[None, 'Y', None], [None, None, None], ['X', None, 'X']]
# [[None, None, 'Y'], [None, None, None], ['X', 'X', None]]
# [[None, None, 'Y'], [None, None, None], ['X', None, 'X']]
# [[None, None, None], ['Y', None, None], ['X', 'X', None]]
# [[None, None, None], ['Y', None, None], ['X', None, 'X']]
# [[None, None, None], [None, 'Y', None], ['X', 'X', None]]
# [[None, None, None], [None, 'Y', None], ['X', None, 'X']]
# [[None, None, None], [None, None, 'Y'], ['X', 'X', None]]
# [[None, None, None], [None, None, 'Y'], ['X', None, 'X']]
# [[None, None, None], [None, None, None], ['X', 'X', 'Y']]
# [['Y', None, None], [None, None, None], [None, 'X', 'X']]
# [[None, 'Y', None], [None, None, None], [None, 'X', 'X']]
# [[None, None, 'Y'], [None, None, None], [None, 'X', 'X']]
# [[None, None, None], ['Y', None, None], [None, 'X', 'X']]
# [[None, None, None], [None, 'Y', None], [None, 'X', 'X']]
# [[None, None, None], [None, None, 'Y'], [None, 'X', 'X']]
# [[None, None, None], [None, None, None], ['Y', 'X', 'X']]
# [['X', 'Y', 'X'], ['Y', None, None], [None, None, None]]
# [['X', 'Y', 'X'], [None, 'Y', None], [None, None, None]]
# [['X', 'Y', 'X'], [None, None, 'Y'], [None, None, None]]
# [['X', 'Y', 'X'], [None, None, None], ['Y', None, None]]
# [['X', 'Y', 'X'], [None, None, None], [None, 'Y', None]]
# [['X', 'Y', 'X'], [None, None, None], [None, None, 'Y']]
# [['X', 'Y', 'Y'], ['X', None, None], [None, None, None]]
# [['X', 'Y', None], ['X', 'Y', None], [None, None, None]]
# [['X', 'Y', None], ['X', None, 'Y'], [None, None, None]]
# [['X', 'Y', None], ['X', None, None], ['Y', None, None]]
# [['X', 'Y', None], ['X', None, None], [None, 'Y', None]]
# [['X', 'Y', None], ['X', None, None], [None, None, 'Y']]
# [['X', 'Y', 'Y'], [None, 'X', None], [None, None, None]]
# [['X', 'Y', None], ['Y', 'X', None], [None, None, None]]
# [['X', 'Y', None], [None, 'X', 'Y'], [None, None, None]]
# [['X', 'Y', None], [None, 'X', None], ['Y', None, None]]
# [['X', 'Y', None], [None, 'X', None], [None, 'Y', None]]
# [['X', 'Y', None], [None, 'X', None], [None, None, 'Y']]
# [['X', 'Y', 'Y'], [None, None, 'X'], [None, None, None]]
# [['X', 'Y', None], ['Y', None, 'X'], [None, None, None]]
# [['X', 'Y', None], [None, 'Y', 'X'], [None, None, None]]
# [['X', 'Y', None], [None, None, 'X'], ['Y', None, None]]
# [['X', 'Y', None], [None, None, 'X'], [None, 'Y', None]]
# [['X', 'Y', None], [None, None, 'X'], [None, None, 'Y']]
# [['X', 'Y', 'Y'], [None, None, None], ['X', None, None]]
# [['X', 'Y', None], ['Y', None, None], ['X', None, None]]
# [['X', 'Y', None], [None, 'Y', None], ['X', None, None]]
# [['X', 'Y', None], [None, None, 'Y'], ['X', None, None]]
# [['X', 'Y', None], [None, None, None], ['X', 'Y', None]]
# [['X', 'Y', None], [None, None, None], ['X', None, 'Y']]
# [['X', 'Y', 'Y'], [None, None, None], [None, 'X', None]]
# [['X', 'Y', None], ['Y', None, None], [None, 'X', None]]
# [['X', 'Y', None], [None, 'Y', None], [None, 'X', None]]
# [['X', 'Y', None], [None, None, 'Y'], [None, 'X', None]]
# [['X', 'Y', None], [None, None, None], ['Y', 'X', None]]
# [['X', 'Y', None], [None, None, None], [None, 'X', 'Y']]
# [['X', 'Y', 'Y'], [None, None, None], [None, None, 'X']]
# [['X', 'Y', None], ['Y', None, None], [None, None, 'X']]
# [['X', 'Y', None], [None, 'Y', None], [None, None, 'X']]
# [['X', 'Y', None], [None, None, 'Y'], [None, None, 'X']]
# [['X', 'Y', None], [None, None, None], ['Y', None, 'X']]
# [['X', 'Y', None], [None, None, None], [None, 'Y', 'X']]
# [['X', 'X', 'Y'], ['Y', None, None], [None, None, None]]
# [['X', 'X', 'Y'], [None, 'Y', None], [None, None, None]]
# [['X', 'X', 'Y'], [None, None, 'Y'], [None, None, None]]
# [['X', 'X', 'Y'], [None, None, None], ['Y', None, None]]
# [['X', 'X', 'Y'], [None, None, None], [None, 'Y', None]]
# [['X', 'X', 'Y'], [None, None, None], [None, None, 'Y']]
# [['X', None, 'Y'], ['X', 'Y', None], [None, None, None]]
# [['X', None, 'Y'], ['X', None, 'Y'], [None, None, None]]
# [['X', None, 'Y'], ['X', None, None], ['Y', None, None]]
# [['X', None, 'Y'], ['X', None, None], [None, 'Y', None]]
# [['X', None, 'Y'], ['X', None, None], [None, None, 'Y']]
# [['X', None, 'Y'], ['Y', 'X', None], [None, None, None]]
# [['X', None, 'Y'], [None, 'X', 'Y'], [None, None, None]]
# [['X', None, 'Y'], [None, 'X', None], ['Y', None, None]]
# [['X', None, 'Y'], [None, 'X', None], [None, 'Y', None]]
# [['X', None, 'Y'], [None, 'X', None], [None, None, 'Y']]
# [['X', None, 'Y'], ['Y', None, 'X'], [None, None, None]]
# [['X', None, 'Y'], [None, 'Y', 'X'], [None, None, None]]
# [['X', None, 'Y'], [None, None, 'X'], ['Y', None, None]]
# [['X', None, 'Y'], [None, None, 'X'], [None, 'Y', None]]
# [['X', None, 'Y'], [None, None, 'X'], [None, None, 'Y']]
# [['X', None, 'Y'], ['Y', None, None], ['X', None, None]]
# [['X', None, 'Y'], [None, 'Y', None], ['X', None, None]]
# [['X', None, 'Y'], [None, None, 'Y'], ['X', None, None]]
# [['X', None, 'Y'], [None, None, None], ['X', 'Y', None]]
# [['X', None, 'Y'], [None, None, None], ['X', None, 'Y']]
# [['X', None, 'Y'], ['Y', None, None], [None, 'X', None]]
# [['X', None, 'Y'], [None, 'Y', None], [None, 'X', None]]
# [['X', None, 'Y'], [None, None, 'Y'], [None, 'X', None]]
# [['X', None, 'Y'], [None, None, None], ['Y', 'X', None]]
# [['X', None, 'Y'], [None, None, None], [None, 'X', 'Y']]
# [['X', None, 'Y'], ['Y', None, None], [None, None, 'X']]
# [['X', None, 'Y'], [None, 'Y', None], [None, None, 'X']]
# [['X', None, 'Y'], [None, None, 'Y'], [None, None, 'X']]
# [['X', None, 'Y'], [None, None, None], ['Y', None, 'X']]
# [['X', None, 'Y'], [None, None, None], [None, 'Y', 'X']]
# [['X', 'X', None], ['Y', 'Y', None], [None, None, None]]
# [['X', 'X', None], ['Y', None, 'Y'], [None, None, None]]
# [['X', 'X', None], ['Y', None, None], ['Y', None, None]]
# [['X', 'X', None], ['Y', None, None], [None, 'Y', None]]
# [['X', 'X', None], ['Y', None, None], [None, None, 'Y']]
# [['X', None, 'X'], ['Y', 'Y', None], [None, None, None]]
# [['X', None, 'X'], ['Y', None, 'Y'], [None, None, None]]
# [['X', None, 'X'], ['Y', None, None], ['Y', None, None]]
# [['X', None, 'X'], ['Y', None, None], [None, 'Y', None]]
# [['X', None, 'X'], ['Y', None, None], [None, None, 'Y']]
# [['X', None, None], ['Y', 'X', 'Y'], [None, None, None]]
# [['X', None, None], ['Y', 'X', None], ['Y', None, None]]
# [['X', None, None], ['Y', 'X', None], [None, 'Y', None]]
# [['X', None, None], ['Y', 'X', None], [None, None, 'Y']]
# [['X', None, None], ['Y', 'Y', 'X'], [None, None, None]]
# [['X', None, None], ['Y', None, 'X'], ['Y', None, None]]
# [['X', None, None], ['Y', None, 'X'], [None, 'Y', None]]
# [['X', None, None], ['Y', None, 'X'], [None, None, 'Y']]
# [['X', None, None], ['Y', 'Y', None], ['X', None, None]]
# [['X', None, None], ['Y', None, 'Y'], ['X', None, None]]
# [['X', None, None], ['Y', None, None], ['X', 'Y', None]]
# [['X', None, None], ['Y', None, None], ['X', None, 'Y']]
# [['X', None, None], ['Y', 'Y', None], [None, 'X', None]]
# [['X', None, None], ['Y', None, 'Y'], [None, 'X', None]]
# [['X', None, None], ['Y', None, None], ['Y', 'X', None]]
# [['X', None, None], ['Y', None, None], [None, 'X', 'Y']]
# [['X', None, None], ['Y', 'Y', None], [None, None, 'X']]
# [['X', None, None], ['Y', None, 'Y'], [None, None, 'X']]
# [['X', None, None], ['Y', None, None], ['Y', None, 'X']]
# [['X', None, None], ['Y', None, None], [None, 'Y', 'X']]
# [['X', 'X', None], [None, 'Y', 'Y'], [None, None, None]]
# [['X', 'X', None], [None, 'Y', None], ['Y', None, None]]
# [['X', 'X', None], [None, 'Y', None], [None, 'Y', None]]
# [['X', 'X', None], [None, 'Y', None], [None, None, 'Y']]
# [['X', None, 'X'], [None, 'Y', 'Y'], [None, None, None]]
# [['X', None, 'X'], [None, 'Y', None], ['Y', None, None]]
# [['X', None, 'X'], [None, 'Y', None], [None, 'Y', None]]
# [['X', None, 'X'], [None, 'Y', None], [None, None, 'Y']]
# [['X', None, None], ['X', 'Y', 'Y'], [None, None, None]]
# [['X', None, None], ['X', 'Y', None], ['Y', None, None]]
# [['X', None, None], ['X', 'Y', None], [None, 'Y', None]]
# [['X', None, None], ['X', 'Y', None], [None, None, 'Y']]
# [['X', None, None], [None, 'Y', 'X'], ['Y', None, None]]
# [['X', None, None], [None, 'Y', 'X'], [None, 'Y', None]]
# [['X', None, None], [None, 'Y', 'X'], [None, None, 'Y']]
# [['X', None, None], [None, 'Y', 'Y'], ['X', None, None]]
# [['X', None, None], [None, 'Y', None], ['X', 'Y', None]]
# [['X', None, None], [None, 'Y', None], ['X', None, 'Y']]
# [['X', None, None], [None, 'Y', 'Y'], [None, 'X', None]]
# [['X', None, None], [None, 'Y', None], ['Y', 'X', None]]
# [['X', None, None], [None, 'Y', None], [None, 'X', 'Y']]
# [['X', None, None], [None, 'Y', 'Y'], [None, None, 'X']]
# [['X', None, None], [None, 'Y', None], ['Y', None, 'X']]
# [['X', None, None], [None, 'Y', None], [None, 'Y', 'X']]
# [['X', 'X', None], [None, None, 'Y'], ['Y', None, None]]
# [['X', 'X', None], [None, None, 'Y'], [None, 'Y', None]]
# [['X', 'X', None], [None, None, 'Y'], [None, None, 'Y']]
# [['X', None, 'X'], [None, None, 'Y'], ['Y', None, None]]
# [['X', None, 'X'], [None, None, 'Y'], [None, 'Y', None]]
# [['X', None, 'X'], [None, None, 'Y'], [None, None, 'Y']]
# [['X', None, None], ['X', None, 'Y'], ['Y', None, None]]
# [['X', None, None], ['X', None, 'Y'], [None, 'Y', None]]
# [['X', None, None], ['X', None, 'Y'], [None, None, 'Y']]
# [['X', None, None], [None, 'X', 'Y'], ['Y', None, None]]
# [['X', None, None], [None, 'X', 'Y'], [None, 'Y', None]]
# [['X', None, None], [None, 'X', 'Y'], [None, None, 'Y']]
# [['X', None, None], [None, None, 'Y'], ['X', 'Y', None]]
# [['X', None, None], [None, None, 'Y'], ['X', None, 'Y']]
# [['X', None, None], [None, None, 'Y'], ['Y', 'X', None]]
# [['X', None, None], [None, None, 'Y'], [None, 'X', 'Y']]
# [['X', None, None], [None, None, 'Y'], ['Y', None, 'X']]
# [['X', None, None], [None, None, 'Y'], [None, 'Y', 'X']]
# [['X', 'X', None], [None, None, None], ['Y', 'Y', None]]
# [['X', 'X', None], [None, None, None], ['Y', None, 'Y']]
# [['X', None, 'X'], [None, None, None], ['Y', 'Y', None]]
# [['X', None, 'X'], [None, None, None], ['Y', None, 'Y']]
# [['X', None, None], ['X', None, None], ['Y', 'Y', None]]
# [['X', None, None], ['X', None, None], ['Y', None, 'Y']]
# [['X', None, None], [None, 'X', None], ['Y', 'Y', None]]
# [['X', None, None], [None, 'X', None], ['Y', None, 'Y']]
# [['X', None, None], [None, None, 'X'], ['Y', 'Y', None]]
# [['X', None, None], [None, None, 'X'], ['Y', None, 'Y']]
# [['X', None, None], [None, None, None], ['Y', 'X', 'Y']]
# [['X', None, None], [None, None, None], ['Y', 'Y', 'X']]
# [['X', 'X', None], [None, None, None], [None, 'Y', 'Y']]
# [['X', None, 'X'], [None, None, None], [None, 'Y', 'Y']]
# [['X', None, None], ['X', None, None], [None, 'Y', 'Y']]
# [['X', None, None], [None, 'X', None], [None, 'Y', 'Y']]
# [['X', None, None], [None, None, 'X'], [None, 'Y', 'Y']]
# [['X', None, None], [None, None, None], ['X', 'Y', 'Y']]
# [['Y', 'X', 'X'], ['Y', None, None], [None, None, None]]
# [['Y', 'X', 'X'], [None, 'Y', None], [None, None, None]]
# [['Y', 'X', 'X'], [None, None, 'Y'], [None, None, None]]
# [['Y', 'X', 'X'], [None, None, None], ['Y', None, None]]
# [['Y', 'X', 'X'], [None, None, None], [None, 'Y', None]]
# [['Y', 'X', 'X'], [None, None, None], [None, None, 'Y']]
# [['Y', 'X', 'Y'], ['X', None, None], [None, None, None]]
# [['Y', 'X', None], ['X', 'Y', None], [None, None, None]]
# [['Y', 'X', None], ['X', None, 'Y'], [None, None, None]]
# [['Y', 'X', None], ['X', None, None], ['Y', None, None]]
# [['Y', 'X', None], ['X', None, None], [None, 'Y', None]]
# [['Y', 'X', None], ['X', None, None], [None, None, 'Y']]
# [['Y', 'X', 'Y'], [None, 'X', None], [None, None, None]]
# [['Y', 'X', None], ['Y', 'X', None], [None, None, None]]
# [['Y', 'X', None], [None, 'X', 'Y'], [None, None, None]]
# [['Y', 'X', None], [None, 'X', None], ['Y', None, None]]
# [['Y', 'X', None], [None, 'X', None], [None, 'Y', None]]
# [['Y', 'X', None], [None, 'X', None], [None, None, 'Y']]
# [['Y', 'X', 'Y'], [None, None, 'X'], [None, None, None]]
# [['Y', 'X', None], ['Y', None, 'X'], [None, None, None]]
# [['Y', 'X', None], [None, 'Y', 'X'], [None, None, None]]
# [['Y', 'X', None], [None, None, 'X'], ['Y', None, None]]
# [['Y', 'X', None], [None, None, 'X'], [None, 'Y', None]]
# [['Y', 'X', None], [None, None, 'X'], [None, None, 'Y']]
# [['Y', 'X', 'Y'], [None, None, None], ['X', None, None]]
# [['Y', 'X', None], ['Y', None, None], ['X', None, None]]
# [['Y', 'X', None], [None, 'Y', None], ['X', None, None]]
# [['Y', 'X', None], [None, None, 'Y'], ['X', None, None]]
# [['Y', 'X', None], [None, None, None], ['X', 'Y', None]]
# [['Y', 'X', None], [None, None, None], ['X', None, 'Y']]
# [['Y', 'X', 'Y'], [None, None, None], [None, 'X', None]]
# [['Y', 'X', None], ['Y', None, None], [None, 'X', None]]
# [['Y', 'X', None], [None, 'Y', None], [None, 'X', None]]
# [['Y', 'X', None], [None, None, 'Y'], [None, 'X', None]]
# [['Y', 'X', None], [None, None, None], ['Y', 'X', None]]
# [['Y', 'X', None], [None, None, None], [None, 'X', 'Y']]
# [['Y', 'X', 'Y'], [None, None, None], [None, None, 'X']]
# [['Y', 'X', None], ['Y', None, None], [None, None, 'X']]
# [['Y', 'X', None], [None, 'Y', None], [None, None, 'X']]
# [['Y', 'X', None], [None, None, 'Y'], [None, None, 'X']]
# [['Y', 'X', None], [None, None, None], ['Y', None, 'X']]
# [['Y', 'X', None], [None, None, None], [None, 'Y', 'X']]
# [[None, 'X', 'Y'], ['X', 'Y', None], [None, None, None]]
# [[None, 'X', 'Y'], ['X', None, 'Y'], [None, None, None]]
# [[None, 'X', 'Y'], ['X', None, None], ['Y', None, None]]
# [[None, 'X', 'Y'], ['X', None, None], [None, 'Y', None]]
# [[None, 'X', 'Y'], ['X', None, None], [None, None, 'Y']]
# [[None, 'X', 'Y'], ['Y', 'X', None], [None, None, None]]
# [[None, 'X', 'Y'], [None, 'X', 'Y'], [None, None, None]]
# [[None, 'X', 'Y'], [None, 'X', None], ['Y', None, None]]
# [[None, 'X', 'Y'], [None, 'X', None], [None, 'Y', None]]
# [[None, 'X', 'Y'], [None, 'X', None], [None, None, 'Y']]
# [[None, 'X', 'Y'], ['Y', None, 'X'], [None, None, None]]
# [[None, 'X', 'Y'], [None, 'Y', 'X'], [None, None, None]]
# [[None, 'X', 'Y'], [None, None, 'X'], ['Y', None, None]]
# [[None, 'X', 'Y'], [None, None, 'X'], [None, 'Y', None]]
# [[None, 'X', 'Y'], [None, None, 'X'], [None, None, 'Y']]
# [[None, 'X', 'Y'], ['Y', None, None], ['X', None, None]]
# [[None, 'X', 'Y'], [None, 'Y', None], ['X', None, None]]
# [[None, 'X', 'Y'], [None, None, 'Y'], ['X', None, None]]
# [[None, 'X', 'Y'], [None, None, None], ['X', 'Y', None]]
# [[None, 'X', 'Y'], [None, None, None], ['X', None, 'Y']]
# [[None, 'X', 'Y'], ['Y', None, None], [None, 'X', None]]
# [[None, 'X', 'Y'], [None, 'Y', None], [None, 'X', None]]
# [[None, 'X', 'Y'], [None, None, 'Y'], [None, 'X', None]]
# [[None, 'X', 'Y'], [None, None, None], ['Y', 'X', None]]
# [[None, 'X', 'Y'], [None, None, None], [None, 'X', 'Y']]
# [[None, 'X', 'Y'], ['Y', None, None], [None, None, 'X']]
# [[None, 'X', 'Y'], [None, 'Y', None], [None, None, 'X']]
# [[None, 'X', 'Y'], [None, None, 'Y'], [None, None, 'X']]
# [[None, 'X', 'Y'], [None, None, None], ['Y', None, 'X']]
# [[None, 'X', 'Y'], [None, None, None], [None, 'Y', 'X']]
# [[None, 'X', 'X'], ['Y', 'Y', None], [None, None, None]]
# [[None, 'X', 'X'], ['Y', None, 'Y'], [None, None, None]]
# [[None, 'X', 'X'], ['Y', None, None], ['Y', None, None]]
# [[None, 'X', 'X'], ['Y', None, None], [None, 'Y', None]]
# [[None, 'X', 'X'], ['Y', None, None], [None, None, 'Y']]
# [[None, 'X', None], ['Y', 'X', 'Y'], [None, None, None]]
# [[None, 'X', None], ['Y', 'X', None], ['Y', None, None]]
# [[None, 'X', None], ['Y', 'X', None], [None, 'Y', None]]
# [[None, 'X', None], ['Y', 'X', None], [None, None, 'Y']]
# [[None, 'X', None], ['Y', 'Y', 'X'], [None, None, None]]
# [[None, 'X', None], ['Y', None, 'X'], ['Y', None, None]]
# [[None, 'X', None], ['Y', None, 'X'], [None, 'Y', None]]
# [[None, 'X', None], ['Y', None, 'X'], [None, None, 'Y']]
# [[None, 'X', None], ['Y', 'Y', None], ['X', None, None]]
# [[None, 'X', None], ['Y', None, 'Y'], ['X', None, None]]
# [[None, 'X', None], ['Y', None, None], ['X', 'Y', None]]
# [[None, 'X', None], ['Y', None, None], ['X', None, 'Y']]
# [[None, 'X', None], ['Y', 'Y', None], [None, 'X', None]]
# [[None, 'X', None], ['Y', None, 'Y'], [None, 'X', None]]
# [[None, 'X', None], ['Y', None, None], ['Y', 'X', None]]
# [[None, 'X', None], ['Y', None, None], [None, 'X', 'Y']]
# [[None, 'X', None], ['Y', 'Y', None], [None, None, 'X']]
# [[None, 'X', None], ['Y', None, 'Y'], [None, None, 'X']]
# [[None, 'X', None], ['Y', None, None], ['Y', None, 'X']]
# [[None, 'X', None], ['Y', None, None], [None, 'Y', 'X']]
# [[None, 'X', 'X'], [None, 'Y', 'Y'], [None, None, None]]
# [[None, 'X', 'X'], [None, 'Y', None], ['Y', None, None]]
# [[None, 'X', 'X'], [None, 'Y', None], [None, 'Y', None]]
# [[None, 'X', 'X'], [None, 'Y', None], [None, None, 'Y']]
# [[None, 'X', None], ['X', 'Y', 'Y'], [None, None, None]]
# [[None, 'X', None], ['X', 'Y', None], ['Y', None, None]]
# [[None, 'X', None], ['X', 'Y', None], [None, 'Y', None]]
# [[None, 'X', None], ['X', 'Y', None], [None, None, 'Y']]
# [[None, 'X', None], [None, 'Y', 'X'], ['Y', None, None]]
# [[None, 'X', None], [None, 'Y', 'X'], [None, 'Y', None]]
# [[None, 'X', None], [None, 'Y', 'X'], [None, None, 'Y']]
# [[None, 'X', None], [None, 'Y', 'Y'], ['X', None, None]]
# [[None, 'X', None], [None, 'Y', None], ['X', 'Y', None]]
# [[None, 'X', None], [None, 'Y', None], ['X', None, 'Y']]
# [[None, 'X', None], [None, 'Y', 'Y'], [None, 'X', None]]
# [[None, 'X', None], [None, 'Y', None], ['Y', 'X', None]]
# [[None, 'X', None], [None, 'Y', None], [None, 'X', 'Y']]
# [[None, 'X', None], [None, 'Y', 'Y'], [None, None, 'X']]
# [[None, 'X', None], [None, 'Y', None], ['Y', None, 'X']]
# [[None, 'X', None], [None, 'Y', None], [None, 'Y', 'X']]
# [[None, 'X', 'X'], [None, None, 'Y'], ['Y', None, None]]
# [[None, 'X', 'X'], [None, None, 'Y'], [None, 'Y', None]]
# [[None, 'X', 'X'], [None, None, 'Y'], [None, None, 'Y']]
# [[None, 'X', None], ['X', None, 'Y'], ['Y', None, None]]
# [[None, 'X', None], ['X', None, 'Y'], [None, 'Y', None]]
# [[None, 'X', None], ['X', None, 'Y'], [None, None, 'Y']]
# [[None, 'X', None], [None, 'X', 'Y'], ['Y', None, None]]
# [[None, 'X', None], [None, 'X', 'Y'], [None, 'Y', None]]
# [[None, 'X', None], [None, 'X', 'Y'], [None, None, 'Y']]
# [[None, 'X', None], [None, None, 'Y'], ['X', 'Y', None]]
# [[None, 'X', None], [None, None, 'Y'], ['X', None, 'Y']]
# [[None, 'X', None], [None, None, 'Y'], ['Y', 'X', None]]
# [[None, 'X', None], [None, None, 'Y'], [None, 'X', 'Y']]
# [[None, 'X', None], [None, None, 'Y'], ['Y', None, 'X']]
# [[None, 'X', None], [None, None, 'Y'], [None, 'Y', 'X']]
# [[None, 'X', 'X'], [None, None, None], ['Y', 'Y', None]]
# [[None, 'X', 'X'], [None, None, None], ['Y', None, 'Y']]
# [[None, 'X', None], ['X', None, None], ['Y', 'Y', None]]
# [[None, 'X', None], ['X', None, None], ['Y', None, 'Y']]
# [[None, 'X', None], [None, 'X', None], ['Y', 'Y', None]]
# [[None, 'X', None], [None, 'X', None], ['Y', None, 'Y']]
# [[None, 'X', None], [None, None, 'X'], ['Y', 'Y', None]]
# [[None, 'X', None], [None, None, 'X'], ['Y', None, 'Y']]
# [[None, 'X', None], [None, None, None], ['Y', 'X', 'Y']]
# [[None, 'X', None], [None, None, None], ['Y', 'Y', 'X']]
# [[None, 'X', 'X'], [None, None, None], [None, 'Y', 'Y']]
# [[None, 'X', None], ['X', None, None], [None, 'Y', 'Y']]
# [[None, 'X', None], [None, 'X', None], [None, 'Y', 'Y']]
# [[None, 'X', None], [None, None, 'X'], [None, 'Y', 'Y']]
# [[None, 'X', None], [None, None, None], ['X', 'Y', 'Y']]
# [['Y', 'Y', 'X'], ['X', None, None], [None, None, None]]
# [['Y', None, 'X'], ['X', 'Y', None], [None, None, None]]
# [['Y', None, 'X'], ['X', None, 'Y'], [None, None, None]]
# [['Y', None, 'X'], ['X', None, None], ['Y', None, None]]
# [['Y', None, 'X'], ['X', None, None], [None, 'Y', None]]
# [['Y', None, 'X'], ['X', None, None], [None, None, 'Y']]
# [['Y', 'Y', 'X'], [None, 'X', None], [None, None, None]]
# [['Y', None, 'X'], ['Y', 'X', None], [None, None, None]]
# [['Y', None, 'X'], [None, 'X', 'Y'], [None, None, None]]
# [['Y', None, 'X'], [None, 'X', None], ['Y', None, None]]
# [['Y', None, 'X'], [None, 'X', None], [None, 'Y', None]]
# [['Y', None, 'X'], [None, 'X', None], [None, None, 'Y']]
# [['Y', 'Y', 'X'], [None, None, 'X'], [None, None, None]]
# [['Y', None, 'X'], ['Y', None, 'X'], [None, None, None]]
# [['Y', None, 'X'], [None, 'Y', 'X'], [None, None, None]]
# [['Y', None, 'X'], [None, None, 'X'], ['Y', None, None]]
# [['Y', None, 'X'], [None, None, 'X'], [None, 'Y', None]]
# [['Y', None, 'X'], [None, None, 'X'], [None, None, 'Y']]
# [['Y', 'Y', 'X'], [None, None, None], ['X', None, None]]
# [['Y', None, 'X'], ['Y', None, None], ['X', None, None]]
# [['Y', None, 'X'], [None, 'Y', None], ['X', None, None]]
# [['Y', None, 'X'], [None, None, 'Y'], ['X', None, None]]
# [['Y', None, 'X'], [None, None, None], ['X', 'Y', None]]
# [['Y', None, 'X'], [None, None, None], ['X', None, 'Y']]
# [['Y', 'Y', 'X'], [None, None, None], [None, 'X', None]]
# [['Y', None, 'X'], ['Y', None, None], [None, 'X', None]]
# [['Y', None, 'X'], [None, 'Y', None], [None, 'X', None]]
# [['Y', None, 'X'], [None, None, 'Y'], [None, 'X', None]]
# [['Y', None, 'X'], [None, None, None], ['Y', 'X', None]]
# [['Y', None, 'X'], [None, None, None], [None, 'X', 'Y']]
# [['Y', 'Y', 'X'], [None, None, None], [None, None, 'X']]
# [['Y', None, 'X'], ['Y', None, None], [None, None, 'X']]
# [['Y', None, 'X'], [None, 'Y', None], [None, None, 'X']]
# [['Y', None, 'X'], [None, None, 'Y'], [None, None, 'X']]
# [['Y', None, 'X'], [None, None, None], ['Y', None, 'X']]
# [['Y', None, 'X'], [None, None, None], [None, 'Y', 'X']]
# [[None, 'Y', 'X'], ['X', 'Y', None], [None, None, None]]
# [[None, 'Y', 'X'], ['X', None, 'Y'], [None, None, None]]
# [[None, 'Y', 'X'], ['X', None, None], ['Y', None, None]]
# [[None, 'Y', 'X'], ['X', None, None], [None, 'Y', None]]
# [[None, 'Y', 'X'], ['X', None, None], [None, None, 'Y']]
# [[None, 'Y', 'X'], ['Y', 'X', None], [None, None, None]]
# [[None, 'Y', 'X'], [None, 'X', 'Y'], [None, None, None]]
# [[None, 'Y', 'X'], [None, 'X', None], ['Y', None, None]]
# [[None, 'Y', 'X'], [None, 'X', None], [None, 'Y', None]]
# [[None, 'Y', 'X'], [None, 'X', None], [None, None, 'Y']]
# [[None, 'Y', 'X'], ['Y', None, 'X'], [None, None, None]]
# [[None, 'Y', 'X'], [None, 'Y', 'X'], [None, None, None]]
# [[None, 'Y', 'X'], [None, None, 'X'], ['Y', None, None]]
# [[None, 'Y', 'X'], [None, None, 'X'], [None, 'Y', None]]
# [[None, 'Y', 'X'], [None, None, 'X'], [None, None, 'Y']]
# [[None, 'Y', 'X'], ['Y', None, None], ['X', None, None]]
# [[None, 'Y', 'X'], [None, 'Y', None], ['X', None, None]]
# [[None, 'Y', 'X'], [None, None, 'Y'], ['X', None, None]]
# [[None, 'Y', 'X'], [None, None, None], ['X', 'Y', None]]
# [[None, 'Y', 'X'], [None, None, None], ['X', None, 'Y']]
# [[None, 'Y', 'X'], ['Y', None, None], [None, 'X', None]]
# [[None, 'Y', 'X'], [None, 'Y', None], [None, 'X', None]]
# [[None, 'Y', 'X'], [None, None, 'Y'], [None, 'X', None]]
# [[None, 'Y', 'X'], [None, None, None], ['Y', 'X', None]]
# [[None, 'Y', 'X'], [None, None, None], [None, 'X', 'Y']]
# [[None, 'Y', 'X'], ['Y', None, None], [None, None, 'X']]
# [[None, 'Y', 'X'], [None, 'Y', None], [None, None, 'X']]
# [[None, 'Y', 'X'], [None, None, 'Y'], [None, None, 'X']]
# [[None, 'Y', 'X'], [None, None, None], ['Y', None, 'X']]
# [[None, 'Y', 'X'], [None, None, None], [None, 'Y', 'X']]
# [[None, None, 'X'], ['Y', 'X', 'Y'], [None, None, None]]
# [[None, None, 'X'], ['Y', 'X', None], ['Y', None, None]]
# [[None, None, 'X'], ['Y', 'X', None], [None, 'Y', None]]
# [[None, None, 'X'], ['Y', 'X', None], [None, None, 'Y']]
# [[None, None, 'X'], ['Y', 'Y', 'X'], [None, None, None]]
# [[None, None, 'X'], ['Y', None, 'X'], ['Y', None, None]]
# [[None, None, 'X'], ['Y', None, 'X'], [None, 'Y', None]]
# [[None, None, 'X'], ['Y', None, 'X'], [None, None, 'Y']]
# [[None, None, 'X'], ['Y', 'Y', None], ['X', None, None]]
# [[None, None, 'X'], ['Y', None, 'Y'], ['X', None, None]]
# [[None, None, 'X'], ['Y', None, None], ['X', 'Y', None]]
# [[None, None, 'X'], ['Y', None, None], ['X', None, 'Y']]
# [[None, None, 'X'], ['Y', 'Y', None], [None, 'X', None]]
# [[None, None, 'X'], ['Y', None, 'Y'], [None, 'X', None]]
# [[None, None, 'X'], ['Y', None, None], ['Y', 'X', None]]
# [[None, None, 'X'], ['Y', None, None], [None, 'X', 'Y']]
# [[None, None, 'X'], ['Y', 'Y', None], [None, None, 'X']]
# [[None, None, 'X'], ['Y', None, 'Y'], [None, None, 'X']]
# [[None, None, 'X'], ['Y', None, None], ['Y', None, 'X']]
# [[None, None, 'X'], ['Y', None, None], [None, 'Y', 'X']]
# [[None, None, 'X'], ['X', 'Y', 'Y'], [None, None, None]]
# [[None, None, 'X'], ['X', 'Y', None], ['Y', None, None]]
# [[None, None, 'X'], ['X', 'Y', None], [None, 'Y', None]]
# [[None, None, 'X'], ['X', 'Y', None], [None, None, 'Y']]
# [[None, None, 'X'], [None, 'Y', 'X'], ['Y', None, None]]
# [[None, None, 'X'], [None, 'Y', 'X'], [None, 'Y', None]]
# [[None, None, 'X'], [None, 'Y', 'X'], [None, None, 'Y']]
# [[None, None, 'X'], [None, 'Y', 'Y'], ['X', None, None]]
# [[None, None, 'X'], [None, 'Y', None], ['X', 'Y', None]]
# [[None, None, 'X'], [None, 'Y', None], ['X', None, 'Y']]
# [[None, None, 'X'], [None, 'Y', 'Y'], [None, 'X', None]]
# [[None, None, 'X'], [None, 'Y', None], ['Y', 'X', None]]
# [[None, None, 'X'], [None, 'Y', None], [None, 'X', 'Y']]
# [[None, None, 'X'], [None, 'Y', 'Y'], [None, None, 'X']]
# [[None, None, 'X'], [None, 'Y', None], ['Y', None, 'X']]
# [[None, None, 'X'], [None, 'Y', None], [None, 'Y', 'X']]
# [[None, None, 'X'], ['X', None, 'Y'], ['Y', None, None]]
# [[None, None, 'X'], ['X', None, 'Y'], [None, 'Y', None]]
# [[None, None, 'X'], ['X', None, 'Y'], [None, None, 'Y']]
# [[None, None, 'X'], [None, 'X', 'Y'], ['Y', None, None]]
# [[None, None, 'X'], [None, 'X', 'Y'], [None, 'Y', None]]
# [[None, None, 'X'], [None, 'X', 'Y'], [None, None, 'Y']]
# [[None, None, 'X'], [None, None, 'Y'], ['X', 'Y', None]]
# [[None, None, 'X'], [None, None, 'Y'], ['X', None, 'Y']]
# [[None, None, 'X'], [None, None, 'Y'], ['Y', 'X', None]]
# [[None, None, 'X'], [None, None, 'Y'], [None, 'X', 'Y']]
# [[None, None, 'X'], [None, None, 'Y'], ['Y', None, 'X']]
# [[None, None, 'X'], [None, None, 'Y'], [None, 'Y', 'X']]
# [[None, None, 'X'], ['X', None, None], ['Y', 'Y', None]]
# [[None, None, 'X'], ['X', None, None], ['Y', None, 'Y']]
# [[None, None, 'X'], [None, 'X', None], ['Y', 'Y', None]]
# [[None, None, 'X'], [None, 'X', None], ['Y', None, 'Y']]
# [[None, None, 'X'], [None, None, 'X'], ['Y', 'Y', None]]
# [[None, None, 'X'], [None, None, 'X'], ['Y', None, 'Y']]
# [[None, None, 'X'], [None, None, None], ['Y', 'X', 'Y']]
# [[None, None, 'X'], [None, None, None], ['Y', 'Y', 'X']]
# [[None, None, 'X'], ['X', None, None], [None, 'Y', 'Y']]
# [[None, None, 'X'], [None, 'X', None], [None, 'Y', 'Y']]
# [[None, None, 'X'], [None, None, 'X'], [None, 'Y', 'Y']]
# [[None, None, 'X'], [None, None, None], ['X', 'Y', 'Y']]
# [['Y', 'Y', None], ['X', 'X', None], [None, None, None]]
# [['Y', None, 'Y'], ['X', 'X', None], [None, None, None]]
# [['Y', None, None], ['X', 'X', 'Y'], [None, None, None]]
# [['Y', None, None], ['X', 'X', None], ['Y', None, None]]
# [['Y', None, None], ['X', 'X', None], [None, 'Y', None]]
# [['Y', None, None], ['X', 'X', None], [None, None, 'Y']]
# [['Y', 'Y', None], ['X', None, 'X'], [None, None, None]]
# [['Y', None, 'Y'], ['X', None, 'X'], [None, None, None]]
# [['Y', None, None], ['X', 'Y', 'X'], [None, None, None]]
# [['Y', None, None], ['X', None, 'X'], ['Y', None, None]]
# [['Y', None, None], ['X', None, 'X'], [None, 'Y', None]]
# [['Y', None, None], ['X', None, 'X'], [None, None, 'Y']]
# [['Y', 'Y', None], ['X', None, None], ['X', None, None]]
# [['Y', None, 'Y'], ['X', None, None], ['X', None, None]]
# [['Y', None, None], ['X', 'Y', None], ['X', None, None]]
# [['Y', None, None], ['X', None, 'Y'], ['X', None, None]]
# [['Y', None, None], ['X', None, None], ['X', 'Y', None]]
# [['Y', None, None], ['X', None, None], ['X', None, 'Y']]
# [['Y', 'Y', None], ['X', None, None], [None, 'X', None]]
# [['Y', None, 'Y'], ['X', None, None], [None, 'X', None]]
# [['Y', None, None], ['X', 'Y', None], [None, 'X', None]]
# [['Y', None, None], ['X', None, 'Y'], [None, 'X', None]]
# [['Y', None, None], ['X', None, None], ['Y', 'X', None]]
# [['Y', None, None], ['X', None, None], [None, 'X', 'Y']]
# [['Y', 'Y', None], ['X', None, None], [None, None, 'X']]
# [['Y', None, 'Y'], ['X', None, None], [None, None, 'X']]
# [['Y', None, None], ['X', 'Y', None], [None, None, 'X']]
# [['Y', None, None], ['X', None, 'Y'], [None, None, 'X']]
# [['Y', None, None], ['X', None, None], ['Y', None, 'X']]
# [['Y', None, None], ['X', None, None], [None, 'Y', 'X']]
# [[None, 'Y', 'Y'], ['X', 'X', None], [None, None, None]]
# [[None, 'Y', None], ['X', 'X', 'Y'], [None, None, None]]
# [[None, 'Y', None], ['X', 'X', None], ['Y', None, None]]
# [[None, 'Y', None], ['X', 'X', None], [None, 'Y', None]]
# [[None, 'Y', None], ['X', 'X', None], [None, None, 'Y']]
# [[None, 'Y', 'Y'], ['X', None, 'X'], [None, None, None]]
# [[None, 'Y', None], ['X', 'Y', 'X'], [None, None, None]]
# [[None, 'Y', None], ['X', None, 'X'], ['Y', None, None]]
# [[None, 'Y', None], ['X', None, 'X'], [None, 'Y', None]]
# [[None, 'Y', None], ['X', None, 'X'], [None, None, 'Y']]
# [[None, 'Y', 'Y'], ['X', None, None], ['X', None, None]]
# [[None, 'Y', None], ['X', 'Y', None], ['X', None, None]]
# ...
# [['X', 'Y', 'Y'], ['X', None, 'Y'], ['X', 'X', 'Y']]
# [['X', 'Y', 'Y'], ['X', None, 'Y'], ['X', 'Y', 'X']]
# [['X', 'Y', 'Y'], ['X', 'Y', 'Y'], [None, 'X', 'X']]
# [['X', 'Y', 'Y'], ['X', None, 'Y'], ['Y', 'X', 'X']]
# [['X', 'Y', None], ['X', 'Y', 'X'], ['Y', 'X', 'Y']]
# [['X', 'Y', None], ['X', 'Y', 'X'], ['Y', 'Y', 'X']]
# [['X', 'Y', None], ['X', 'Y', 'X'], ['X', 'Y', 'Y']]
# [['X', 'Y', None], ['X', 'Y', 'Y'], ['X', 'X', 'Y']]
# [['X', 'Y', None], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [['X', 'Y', None], ['X', 'Y', 'Y'], ['Y', 'X', 'X']]
# [['X', 'Y', None], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['X', 'Y', None], ['X', 'X', 'Y'], ['X', 'Y', 'Y']]
# [['X', 'Y', 'Y'], ['Y', 'X', 'X'], ['X', 'Y', None]]
# [['X', 'Y', 'Y'], ['Y', 'X', 'X'], ['X', None, 'Y']]
# [['X', 'Y', 'Y'], ['Y', 'X', 'X'], ['Y', 'X', None]]
# [['X', 'Y', 'Y'], ['Y', 'X', 'X'], [None, 'X', 'Y']]
# [['X', 'Y', 'Y'], [None, 'X', 'X'], ['Y', 'X', 'Y']]
# [['X', 'Y', 'Y'], [None, 'X', 'X'], ['X', 'Y', 'Y']]
# [['X', 'Y', 'Y'], ['Y', 'X', 'Y'], ['X', 'X', None]]
# [['X', 'Y', 'Y'], ['Y', 'X', None], ['X', 'X', 'Y']]
# [['X', 'Y', 'Y'], [None, 'X', 'Y'], ['X', 'X', 'Y']]
# [['X', 'Y', None], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [['X', 'Y', None], ['Y', 'X', 'X'], ['X', 'Y', 'Y']]
# [['X', 'Y', None], ['Y', 'X', 'Y'], ['X', 'X', 'Y']]
# [['X', 'Y', 'Y'], ['Y', 'Y', 'X'], ['X', 'X', None]]
# [['X', 'Y', 'Y'], ['Y', None, 'X'], ['X', 'X', 'Y']]
# [['X', 'Y', 'Y'], ['Y', 'Y', 'X'], ['X', None, 'X']]
# [['X', 'Y', 'Y'], ['Y', None, 'X'], ['X', 'Y', 'X']]
# [['X', 'Y', 'Y'], [None, 'Y', 'X'], ['X', 'X', 'Y']]
# [['X', 'Y', 'Y'], [None, 'Y', 'X'], ['X', 'Y', 'X']]
# [['X', 'Y', 'Y'], ['Y', 'Y', 'X'], [None, 'X', 'X']]
# [['X', 'Y', 'Y'], ['Y', None, 'X'], ['Y', 'X', 'X']]
# [['X', 'Y', None], ['Y', 'Y', 'X'], ['X', 'X', 'Y']]
# [['X', 'Y', None], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [['X', 'Y', None], ['Y', 'Y', 'X'], ['Y', 'X', 'X']]
# [['X', 'X', 'Y'], ['Y', 'X', 'Y'], ['X', 'Y', None]]
# [['X', 'X', 'Y'], ['Y', 'X', 'Y'], ['X', None, 'Y']]
# [['X', 'X', 'Y'], ['Y', 'X', 'Y'], ['Y', 'X', None]]
# [['X', 'X', 'Y'], ['Y', 'X', 'Y'], [None, 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'X', 'X'], ['Y', 'Y', None]]
# [['X', 'X', 'Y'], ['Y', 'X', 'X'], ['Y', None, 'Y']]
# [['X', 'X', 'Y'], ['Y', 'X', None], ['Y', 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'X', 'X'], [None, 'Y', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'X', None], ['X', 'Y', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'Y', 'X'], ['X', 'Y', None]]
# [['X', 'X', 'Y'], ['Y', 'Y', 'X'], ['X', None, 'Y']]
# [['X', 'X', 'Y'], ['Y', 'Y', 'X'], [None, 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'Y', 'X'], [None, 'Y', 'X']]
# [['X', 'X', 'Y'], ['Y', None, 'X'], ['Y', 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', None, 'X'], ['Y', 'Y', 'X']]
# [['X', 'X', 'Y'], ['Y', None, 'X'], ['X', 'Y', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'Y', None], ['X', 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', 'Y', None], ['X', 'Y', 'X']]
# [['X', 'X', 'Y'], ['Y', None, 'Y'], ['X', 'X', 'Y']]
# [['X', 'X', 'Y'], ['Y', None, 'Y'], ['X', 'Y', 'X']]
# [['X', 'X', 'Y'], ['Y', None, 'Y'], ['Y', 'X', 'X']]
# [['X', 'X', 'Y'], ['X', 'Y', 'Y'], ['X', 'Y', None]]
# [['X', 'X', 'Y'], ['X', 'Y', 'Y'], ['X', None, 'Y']]
# [['X', 'X', 'Y'], ['X', 'Y', 'Y'], [None, 'X', 'Y']]
# [['X', 'X', 'Y'], ['X', 'Y', 'Y'], [None, 'Y', 'X']]
# [['X', 'X', 'Y'], ['X', 'Y', 'X'], [None, 'Y', 'Y']]
# [['X', 'X', 'Y'], ['X', 'Y', None], ['X', 'Y', 'Y']]
# [['X', 'X', 'Y'], [None, 'Y', 'X'], ['X', 'Y', 'Y']]
# [['X', 'X', 'Y'], [None, 'Y', 'Y'], ['X', 'X', 'Y']]
# [['X', 'X', 'Y'], [None, 'Y', 'Y'], ['X', 'Y', 'X']]
# [['X', 'X', 'Y'], ['X', 'X', 'Y'], ['Y', 'Y', None]]
# [['X', 'X', 'Y'], ['X', 'X', 'Y'], ['Y', None, 'Y']]
# [['X', 'X', 'Y'], ['X', None, 'Y'], ['Y', 'X', 'Y']]
# [['X', 'X', 'Y'], ['X', None, 'Y'], ['Y', 'Y', 'X']]
# [['X', 'X', 'Y'], ['X', 'X', 'Y'], [None, 'Y', 'Y']]
# [['X', 'X', 'Y'], ['X', None, 'Y'], ['X', 'Y', 'Y']]
# [['X', 'X', 'Y'], [None, 'X', 'Y'], ['Y', 'X', 'Y']]
# [['X', 'X', 'Y'], [None, 'X', 'Y'], ['X', 'Y', 'Y']]
# [['X', None, 'Y'], ['X', 'Y', 'X'], ['X', 'Y', 'Y']]
# [['X', None, 'Y'], ['X', 'Y', 'Y'], ['X', 'X', 'Y']]
# [['X', None, 'Y'], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [['X', None, 'Y'], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['X', None, 'Y'], ['X', 'X', 'Y'], ['X', 'Y', 'Y']]
# [['X', None, 'Y'], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [['X', None, 'Y'], ['Y', 'X', 'X'], ['X', 'Y', 'Y']]
# [['X', None, 'Y'], ['Y', 'X', 'Y'], ['X', 'X', 'Y']]
# [['X', None, 'Y'], ['Y', 'Y', 'X'], ['X', 'X', 'Y']]
# [['X', None, 'Y'], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [['X', 'X', None], ['Y', 'Y', 'X'], ['Y', 'X', 'Y']]
# [['X', 'X', None], ['Y', 'Y', 'X'], ['Y', 'Y', 'X']]
# [['X', 'X', None], ['Y', 'Y', 'X'], ['X', 'Y', 'Y']]
# [['X', 'X', None], ['Y', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['X', 'X', None], ['Y', 'X', 'Y'], ['X', 'Y', 'Y']]
# [['X', None, 'X'], ['Y', 'Y', 'X'], ['Y', 'X', 'Y']]
# [['X', None, 'X'], ['Y', 'Y', 'X'], ['Y', 'Y', 'X']]
# [['X', None, 'X'], ['Y', 'Y', 'X'], ['X', 'Y', 'Y']]
# [['X', None, 'X'], ['Y', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['X', 'X', None], ['X', 'Y', 'Y'], ['Y', 'X', 'Y']]
# [['X', 'X', None], ['X', 'Y', 'Y'], ['Y', 'Y', 'X']]
# [['X', 'X', None], ['X', 'Y', 'Y'], ['X', 'Y', 'Y']]
# [['X', None, 'X'], ['X', 'Y', 'Y'], ['Y', 'X', 'Y']]
# [['X', None, 'X'], ['X', 'Y', 'Y'], ['Y', 'Y', 'X']]
# [['X', None, 'X'], ['X', 'Y', 'Y'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'X'], ['Y', 'X', 'Y'], ['Y', 'X', None]]
# [['Y', 'X', 'X'], ['Y', 'X', 'Y'], [None, 'X', 'Y']]
# [['Y', 'X', 'X'], ['Y', 'X', 'Y'], ['Y', None, 'X']]
# [['Y', 'X', 'X'], ['Y', 'X', 'Y'], [None, 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', 'X', 'X'], ['Y', 'Y', None]]
# [['Y', 'X', 'X'], ['Y', 'X', 'X'], ['Y', None, 'Y']]
# [['Y', 'X', 'X'], ['Y', 'X', None], ['Y', 'X', 'Y']]
# [['Y', 'X', 'X'], ['Y', 'X', None], ['Y', 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', 'X', 'X'], [None, 'Y', 'Y']]
# [['Y', 'X', 'X'], ['Y', 'Y', 'X'], ['X', 'Y', None]]
# [['Y', 'X', 'X'], ['Y', 'Y', 'X'], ['Y', 'X', None]]
# [['Y', 'X', 'X'], ['Y', 'Y', 'X'], ['Y', None, 'X']]
# [['Y', 'X', 'X'], ['Y', 'Y', 'X'], [None, 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', None, 'X'], ['Y', 'X', 'Y']]
# [['Y', 'X', 'X'], ['Y', None, 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', None, 'X'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'X'], ['Y', 'Y', None], ['X', 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', None, 'Y'], ['X', 'X', 'Y']]
# [['Y', 'X', 'X'], ['Y', None, 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', 'X'], ['Y', 'Y', None], ['Y', 'X', 'X']]
# [['Y', 'X', 'X'], ['Y', None, 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', 'X'], ['X', 'Y', 'Y'], ['X', 'Y', None]]
# [['Y', 'X', 'X'], ['X', 'Y', 'Y'], ['Y', 'X', None]]
# [['Y', 'X', 'X'], ['X', 'Y', 'Y'], ['Y', None, 'X']]
# [['Y', 'X', 'X'], ['X', 'Y', 'Y'], [None, 'Y', 'X']]
# [['Y', 'X', 'X'], ['X', 'Y', 'X'], ['Y', 'Y', None]]
# [['Y', 'X', 'X'], ['X', 'Y', None], ['Y', 'Y', 'X']]
# [['Y', 'X', 'X'], [None, 'Y', 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'X'], [None, 'Y', 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', 'X'], [None, 'Y', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', 'X'], ['X', 'X', 'Y'], ['Y', 'Y', None]]
# [['Y', 'X', 'X'], ['X', 'X', 'Y'], ['Y', None, 'Y']]
# [['Y', 'X', 'X'], ['X', None, 'Y'], ['Y', 'X', 'Y']]
# [['Y', 'X', 'X'], ['X', None, 'Y'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'X'], ['X', 'X', 'Y'], [None, 'Y', 'Y']]
# [['Y', 'X', 'X'], ['X', None, 'Y'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'X'], [None, 'X', 'Y'], ['Y', 'X', 'Y']]
# [['Y', 'X', 'X'], [None, 'X', 'Y'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], ['X', 'Y', None]]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], ['X', None, 'Y']]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], ['Y', 'X', None]]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], [None, 'X', 'Y']]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], ['Y', None, 'X']]
# [['Y', 'X', 'Y'], ['X', 'X', 'Y'], [None, 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', 'X', None], ['Y', 'X', 'Y']]
# [['Y', 'X', 'Y'], ['X', 'X', None], ['Y', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', 'X', None], ['X', 'Y', 'Y']]
# [['Y', 'X', 'Y'], ['X', 'Y', 'X'], ['X', 'Y', None]]
# [['Y', 'X', 'Y'], ['X', 'Y', 'X'], [None, 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', None, 'X'], ['Y', 'X', 'Y']]
# [['Y', 'X', 'Y'], ['X', None, 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', None, 'X'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'Y'], ['X', 'Y', 'Y'], ['X', 'X', None]]
# [['Y', 'X', 'Y'], ['X', 'Y', 'Y'], ['X', None, 'X']]
# [['Y', 'X', 'Y'], ['X', 'Y', None], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', None, 'Y'], ['X', 'X', 'Y']]
# [['Y', 'X', 'Y'], ['X', None, 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['X', 'Y', 'Y'], [None, 'X', 'X']]
# [['Y', 'X', 'Y'], ['X', None, 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', None], ['X', 'Y', 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', None], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', None], ['X', 'Y', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', None], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['Y', 'X', None], ['X', 'X', 'Y'], ['Y', 'Y', 'X']]
# [['Y', 'X', None], ['X', 'X', 'Y'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], ['X', 'Y', None]]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], ['X', None, 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], ['Y', 'X', None]]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], [None, 'X', 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], ['Y', None, 'X']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'X'], [None, 'Y', 'X']]
# [['Y', 'X', 'Y'], [None, 'X', 'X'], ['Y', 'X', 'Y']]
# [['Y', 'X', 'Y'], [None, 'X', 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', 'Y'], [None, 'X', 'X'], ['X', 'Y', 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'Y'], ['X', 'X', None]]
# [['Y', 'X', 'Y'], ['Y', 'X', None], ['X', 'X', 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'Y'], ['X', None, 'X']]
# [['Y', 'X', 'Y'], ['Y', 'X', None], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], [None, 'X', 'Y'], ['X', 'X', 'Y']]
# [['Y', 'X', 'Y'], [None, 'X', 'Y'], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['Y', 'X', 'Y'], [None, 'X', 'X']]
# [['Y', 'X', 'Y'], ['Y', 'X', None], ['Y', 'X', 'X']]
# [['Y', 'X', 'Y'], [None, 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', None], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [['Y', 'X', None], ['Y', 'X', 'X'], ['Y', 'Y', 'X']]
# [['Y', 'X', None], ['Y', 'X', 'X'], ['X', 'Y', 'Y']]
# [['Y', 'X', None], ['Y', 'X', 'Y'], ['X', 'X', 'Y']]
# [['Y', 'X', None], ['Y', 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'X', 'Y'], ['Y', 'Y', 'X'], ['X', 'X', None]]
# [['Y', 'X', 'Y'], ['Y', None, 'X'], ['X', 'X', 'Y']]
# [['Y', 'X', 'Y'], ['Y', 'Y', 'X'], ['X', None, 'X']]
# [['Y', 'X', 'Y'], ['Y', None, 'X'], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], [None, 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', 'X', 'Y'], ['Y', 'Y', 'X'], [None, 'X', 'X']]
# [['Y', 'X', 'Y'], ['Y', None, 'X'], ['Y', 'X', 'X']]
# [['Y', 'X', None], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', 'X', None], ['Y', 'Y', 'X'], ['Y', 'X', 'X']]
# [[None, 'X', 'Y'], ['X', 'Y', 'X'], ['X', 'Y', 'Y']]
# [[None, 'X', 'Y'], ['X', 'Y', 'Y'], ['X', 'X', 'Y']]
# [[None, 'X', 'Y'], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [[None, 'X', 'Y'], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [[None, 'X', 'Y'], ['X', 'X', 'Y'], ['Y', 'Y', 'X']]
# [[None, 'X', 'Y'], ['X', 'X', 'Y'], ['X', 'Y', 'Y']]
# [[None, 'X', 'Y'], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [[None, 'X', 'Y'], ['Y', 'X', 'X'], ['Y', 'Y', 'X']]
# [[None, 'X', 'Y'], ['Y', 'X', 'X'], ['X', 'Y', 'Y']]
# [[None, 'X', 'Y'], ['Y', 'X', 'Y'], ['X', 'X', 'Y']]
# [[None, 'X', 'Y'], ['Y', 'X', 'Y'], ['Y', 'X', 'X']]
# [[None, 'X', 'Y'], ['Y', 'Y', 'X'], ['X', 'X', 'Y']]
# [[None, 'X', 'Y'], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [[None, 'X', 'X'], ['Y', 'Y', 'X'], ['Y', 'X', 'Y']]
# [[None, 'X', 'X'], ['Y', 'Y', 'X'], ['Y', 'Y', 'X']]
# [[None, 'X', 'X'], ['Y', 'Y', 'X'], ['X', 'Y', 'Y']]
# [[None, 'X', 'X'], ['Y', 'X', 'Y'], ['Y', 'X', 'Y']]
# [[None, 'X', 'X'], ['Y', 'X', 'Y'], ['Y', 'Y', 'X']]
# [[None, 'X', 'X'], ['X', 'Y', 'Y'], ['Y', 'X', 'Y']]
# [[None, 'X', 'X'], ['X', 'Y', 'Y'], ['Y', 'Y', 'X']]
# [[None, 'X', 'X'], ['X', 'Y', 'Y'], ['X', 'Y', 'Y']]
# [['Y', 'Y', 'X'], ['X', 'X', 'Y'], ['Y', 'X', None]]
# [['Y', 'Y', 'X'], ['X', 'X', 'Y'], [None, 'X', 'Y']]
# [['Y', 'Y', 'X'], ['X', 'X', 'Y'], ['Y', None, 'X']]
# [['Y', 'Y', 'X'], ['X', 'X', 'Y'], [None, 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', 'X', None], ['Y', 'X', 'Y']]
# [['Y', 'Y', 'X'], ['X', 'X', None], ['Y', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', 'Y', 'X'], ['X', 'Y', None]]
# [['Y', 'Y', 'X'], ['X', 'Y', 'X'], ['Y', 'X', None]]
# [['Y', 'Y', 'X'], ['X', 'Y', 'X'], ['Y', None, 'X']]
# [['Y', 'Y', 'X'], ['X', 'Y', 'X'], [None, 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', None, 'X'], ['Y', 'X', 'Y']]
# [['Y', 'Y', 'X'], ['X', None, 'X'], ['Y', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', None, 'X'], ['X', 'Y', 'Y']]
# [['Y', 'Y', 'X'], ['X', 'Y', 'Y'], ['X', 'X', None]]
# [['Y', 'Y', 'X'], ['X', 'Y', 'Y'], ['X', None, 'X']]
# [['Y', 'Y', 'X'], ['X', 'Y', None], ['X', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', None, 'Y'], ['X', 'X', 'Y']]
# [['Y', 'Y', 'X'], ['X', None, 'Y'], ['X', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['X', 'Y', 'Y'], [None, 'X', 'X']]
# [['Y', 'Y', 'X'], ['X', 'Y', None], ['Y', 'X', 'X']]
# [['Y', 'Y', 'X'], ['X', None, 'Y'], ['Y', 'X', 'X']]
# [['Y', None, 'X'], ['X', 'Y', 'X'], ['Y', 'Y', 'X']]
# [['Y', None, 'X'], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [['Y', None, 'X'], ['X', 'Y', 'Y'], ['Y', 'X', 'X']]
# [['Y', None, 'X'], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [['Y', None, 'X'], ['X', 'X', 'Y'], ['Y', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['Y', 'X', 'X'], ['Y', 'X', None]]
# [['Y', 'Y', 'X'], ['Y', 'X', 'X'], [None, 'X', 'Y']]
# [['Y', 'Y', 'X'], ['Y', 'X', 'X'], ['Y', None, 'X']]
# [['Y', 'Y', 'X'], ['Y', 'X', 'X'], [None, 'Y', 'X']]
# [['Y', 'Y', 'X'], [None, 'X', 'X'], ['Y', 'X', 'Y']]
# [['Y', 'Y', 'X'], [None, 'X', 'X'], ['Y', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['Y', 'X', 'Y'], [None, 'X', 'X']]
# [['Y', 'Y', 'X'], ['Y', 'X', None], ['Y', 'X', 'X']]
# [['Y', 'Y', 'X'], [None, 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', None, 'X'], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [['Y', None, 'X'], ['Y', 'X', 'X'], ['Y', 'Y', 'X']]
# [['Y', None, 'X'], ['Y', 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'Y', 'X'], ['Y', 'Y', 'X'], ['X', 'X', None]]
# [['Y', 'Y', 'X'], ['Y', None, 'X'], ['X', 'X', 'Y']]
# [['Y', 'Y', 'X'], ['Y', 'Y', 'X'], ['X', None, 'X']]
# [['Y', 'Y', 'X'], ['Y', None, 'X'], ['X', 'Y', 'X']]
# [['Y', 'Y', 'X'], [None, 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', 'Y', 'X'], ['Y', 'Y', 'X'], [None, 'X', 'X']]
# [['Y', 'Y', 'X'], ['Y', None, 'X'], ['Y', 'X', 'X']]
# [['Y', 'Y', 'X'], [None, 'Y', 'X'], ['Y', 'X', 'X']]
# [['Y', None, 'X'], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', None, 'X'], ['Y', 'Y', 'X'], ['Y', 'X', 'X']]
# [[None, 'Y', 'X'], ['X', 'Y', 'X'], ['Y', 'X', 'Y']]
# [[None, 'Y', 'X'], ['X', 'Y', 'X'], ['Y', 'Y', 'X']]
# [[None, 'Y', 'X'], ['X', 'Y', 'X'], ['X', 'Y', 'Y']]
# [[None, 'Y', 'X'], ['X', 'Y', 'Y'], ['X', 'X', 'Y']]
# [[None, 'Y', 'X'], ['X', 'Y', 'Y'], ['X', 'Y', 'X']]
# [[None, 'Y', 'X'], ['X', 'Y', 'Y'], ['Y', 'X', 'X']]
# [[None, 'Y', 'X'], ['X', 'X', 'Y'], ['Y', 'X', 'Y']]
# [[None, 'Y', 'X'], ['X', 'X', 'Y'], ['Y', 'Y', 'X']]
# [[None, 'Y', 'X'], ['Y', 'X', 'X'], ['Y', 'X', 'Y']]
# [[None, 'Y', 'X'], ['Y', 'X', 'X'], ['Y', 'Y', 'X']]
# [[None, 'Y', 'X'], ['Y', 'X', 'Y'], ['Y', 'X', 'X']]
# [[None, 'Y', 'X'], ['Y', 'Y', 'X'], ['X', 'X', 'Y']]
# [[None, 'Y', 'X'], ['Y', 'Y', 'X'], ['X', 'Y', 'X']]
# [[None, 'Y', 'X'], ['Y', 'Y', 'X'], ['Y', 'X', 'X']]
# [['Y', 'Y', None], ['X', 'X', 'Y'], ['X', 'X', 'Y']]
# [['Y', 'Y', None], ['X', 'X', 'Y'], ['X', 'Y', 'X']]
# [['Y', 'Y', None], ['X', 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', None, 'Y'], ['X', 'X', 'Y'], ['X', 'X', 'Y']]
# [['Y', None, 'Y'], ['X', 'X', 'Y'], ['X', 'Y', 'X']]
# [['Y', None, 'Y'], ['X', 'X', 'Y'], ['Y', 'X', 'X']]
# [['Y', 'Y', None], ['X', 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', 'Y', None], ['X', 'Y', 'X'], ['Y', 'X', 'X']]
# [['Y', None, 'Y'], ['X', 'Y', 'X'], ['X', 'Y', 'X']]
# [[None, 'Y', 'Y'], ['X', 'X', 'Y'], ['X', 'X', 'Y']]
# [[None, 'Y', 'Y'], ['X', 'X', 'Y'], ['X', 'Y', 'X']]
# [[None, 'Y', 'Y'], ['X', 'X', 'Y'], ['Y', 'X', 'X']]
# [[None, 'Y', 'Y'], ['X', 'Y', 'X'], ['X', 'X', 'Y']]
# [[None, 'Y', 'Y'], ['X', 'Y', 'X'], ['X', 'Y', 'X']]
# [['Y', 'Y', None], ['Y', 'X', 'X'], ['X', 'X', 'Y']]
# [['Y', 'Y', None], ['Y', 'X', 'X'], ['X', 'Y', 'X']]
# [['Y', 'Y', None], ['Y', 'X', 'X'], ['Y', 'X', 'X']]
# [['Y', None, 'Y'], ['Y', 'X', 'X'], ['X', 'X', 'Y']]
# [['Y', None, 'Y'], ['Y', 'X', 'X'], ['X', 'Y', 'X']]
# [['Y', None, 'Y'], ['Y', 'X', 'X'], ['Y', 'X', 'X']]
# [[None, 'Y', 'Y'], ['Y', 'X', 'X'], ['X', 'X', 'Y']]
# [[None, 'Y', 'Y'], ['Y', 'X', 'X'], ['X', 'Y', 'X']]
# [[None, 'Y', 'Y'], ['Y', 'X', 'X'], ['Y', 'X', 'X']]

# %%
def genertate_game_space(state):
    if state == init_state:
        # generate game board from initial state
        states_to_be_generated = [init_state]
        states_generated = []
        counter = 0
        player = 'X'
        positions_filled = 0
        level = 0
        while states_to_be_generated:
            current_state_genertaing = states_to_be_generated.pop(0)
            #print ("Generating state...", current_state_genertaing)
            if current_state_genertaing in states_generated or isTerminal(current_state_genertaing):
                continue
            
            # generate current state
            game_board_state[str(current_state_genertaing)] = {
                'states': [],
                'player': None,
                'utility': None
            }
            if level%2==0:
                player = 'X'
            else:
                player = 'Y'
            
            #print ("Successor states...............")
            #print (get_successor_states(current_state_genertaing, player))
            game_board_state[str(current_state_genertaing)]['states'] = get_successor_states(current_state_genertaing, player)
            
            game_board_state[str(current_state_genertaing)]['player'] = player
            if check_if_winning_state(current_state_genertaing, player):
                if player == 'X':
                    game_board_state[str(current_state_genertaing)]['utility'] = 1
                else:
                    game_board_state[str(current_state_genertaing)]['utility'] = -1

            else:
                game_board_state[str(current_state_genertaing)]['utility'] = 0
            # append its successors to states_to_be_generated
            for successor_state in get_successor_states(current_state_genertaing, player):
                #print ("Adding state to stack:.......")
                #print (successor_state)
                if successor_state not in states_to_be_generated and successor_state not in states_generated:
                    states_to_be_generated.append(successor_state)
            counter += 1
            print (counter)
            #print (states_to_be_generated)
            states_generated.append(current_state_genertaing)
            print (len(states_to_be_generated))
            positions_filled += 1
    return game_board_state

genertate_game_space(init_state)

# %%
game_board_state[str([['Y', 'Y', 'X'], [None, 'Y', None], ['X', 'X', None]])]
# Out:
# {'states': [[['Y', 'Y', 'X'], ['X', 'Y', None], ['X', 'X', None]],
#   [['Y', 'Y', 'X'], [None, 'Y', 'X'], ['X', 'X', None]],
#   [['Y', 'Y', 'X'], [None, 'Y', None], ['X', 'X', 'X']]]}

# %%
get_successor_states([[None, None, 'X'], [None, 'X', 'Y'], [None, None, 'Y']], 'Y')
# Out:
# [[['Y', None, 'X'], [None, 'X', 'Y'], [None, None, 'Y']],
#  [[None, 'Y', 'X'], [None, 'X', 'Y'], [None, None, 'Y']],
#  [[None, None, 'X'], ['Y', 'X', 'Y'], [None, None, 'Y']],
#  [[None, None, 'X'], [None, 'X', 'Y'], ['Y', None, 'Y']],
#  [[None, None, 'X'], [None, 'X', 'Y'], [None, 'Y', 'Y']]]

# %% [markdown]
# ### Simple backup

# %% [raw]
# def generate_game_space_by_level(state):
#     if state == init_state:
#         states_to_be_generated_by_level = [[init_state]]
#         level = 0
#         states_generated_by_level = []
#         all_states_generated = []
#         player = 'X'
#         while states_to_be_generated_by_level and level < 9:
#             # all states to be generated at this level
#             print ("Current Level:", level)
#             if level%2 == 0:
#                 player = 'X'
#             else:
#                 player = 'Y'
#             states_to_be_generated_at_level = states_to_be_generated_by_level.pop(0)
#             #print ("Current states:............")
#             #print (states_to_be_generated_at_level)
#             next_level_successor_states = []
#             for current_level_state in states_to_be_generated_at_level:
#                 successor_states = get_successor_states(current_level_state, player)
#                 for successor_state in successor_states:
#                     next_level_successor_states.append(successor_state)
#             states_to_be_generated_by_level.append(next_level_successor_states)
#             level += 1
#             #print ("Next level states:............")
#             #print (next_level_successor_states)
#             print(len(states_to_be_generated_at_level))
#
# generate_game_space_by_level(init_state)
